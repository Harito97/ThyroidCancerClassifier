# %% [markdown]
# # Áp dụng cho data ver 1
#
# Thời gian train trên colab chỉ dùng CPU là 6h33m

# %% [markdown]
# Loading data...
#
# Setting up model to device...
#
# Setting up loss function and optimizer...
#
# Training classification model...
#
# Epoch 1:
#
# Train Loss: 0.954046, Train Acc: 0.506087, Train F1: 0.513509
#
# Val Loss: 0.572363, Val Acc: 0.730769, Val F1: 0.734278
#
# Saved best model at epoch 1
#
# Epoch 2:
#
# Train Loss: 0.689384, Train Acc: 0.680870, Train F1: 0.684537
#
# Val Loss: 0.487320, Val Acc: 0.738462, Val F1: 0.727804
#
# Saved best model at epoch 2
#
# Epoch 3:
#
# Train Loss: 0.598287, Train Acc: 0.686087, Train F1: 0.686994
#
# Val Loss: 0.459699, Val Acc: 0.761538, Val F1: 0.758586
#
# Saved best model at epoch 3
#
# Epoch 4:
#
# Train Loss: 0.537863, Train Acc: 0.717391, Train F1: 0.718145
#
# Val Loss: 0.408202, Val Acc: 0.769231, Val F1: 0.767214
#
# Saved best model at epoch 4
#
# Epoch 5:
#
# Train Loss: 0.551647, Train Acc: 0.699130, Train F1: 0.698699
#
# Val Loss: 0.436591, Val Acc: 0.723077, Val F1: 0.688958
#
# Epoch 6:
#
# Train Loss: 0.536280, Train Acc: 0.692174, Train F1: 0.693923
#
# Val Loss: 0.422351, Val Acc: 0.723077, Val F1: 0.702560
#
# Epoch 7:
#
# Train Loss: 0.504470, Train Acc: 0.722609, Train F1: 0.723312
#
# Val Loss: 0.447167, Val Acc: 0.753846, Val F1: 0.754982
#
# Epoch 8:
#
# Train Loss: 0.529116, Train Acc: 0.745217, Train F1: 0.747083
#
# Val Loss: 0.412191, Val Acc: 0.746154, Val F1: 0.745897
#
# Epoch 9:
#
# Train Loss: 0.494026, Train Acc: 0.739130, Train F1: 0.740548
#
# Val Loss: 0.436566, Val Acc: 0.746154, Val F1: 0.747847
#
# Epoch 10:
#
# Train Loss: 0.462284, Train Acc: 0.751304, Train F1: 0.751465
#
# Val Loss: 0.449520, Val Acc: 0.746154, Val F1: 0.748862
#
# Epoch 11:
#
# Train Loss: 0.459346, Train Acc: 0.740870, Train F1: 0.742615
#
# Val Loss: 0.368354, Val Acc: 0.753846, Val F1: 0.745241
#
# Saved best model at epoch 11
#
# Epoch 12:
#
# Train Loss: 0.425801, Train Acc: 0.763478, Train F1: 0.763843
#
# Val Loss: 0.417815, Val Acc: 0.723077, Val F1: 0.705769
#
# Epoch 13:
#
# Train Loss: 0.477218, Train Acc: 0.737391, Train F1: 0.737941
#
# Val Loss: 0.442836, Val Acc: 0.730769, Val F1: 0.698990
#
# Epoch 14:
#
# Train Loss: 0.496960, Train Acc: 0.743478, Train F1: 0.744309
#
# Val Loss: 0.451434, Val Acc: 0.730769, Val F1: 0.728678
#
# Epoch 15:
#
# Train Loss: 0.436945, Train Acc: 0.763478, Train F1: 0.763847
#
# Val Loss: 0.419896, Val Acc: 0.738462, Val F1: 0.731165
#
# Epoch 16:
#
# Train Loss: 0.445439, Train Acc: 0.754783, Train F1: 0.755456
#
# Val Loss: 0.585802, Val Acc: 0.753846, Val F1: 0.757445
#
# Epoch 17:
#
# Train Loss: 0.435125, Train Acc: 0.735652, Train F1: 0.736557
#
# Val Loss: 0.469953, Val Acc: 0.753846, Val F1: 0.755093
#
# Epoch 18:
#
# Train Loss: 0.426902, Train Acc: 0.757391, Train F1: 0.756601
#
# Val Loss: 0.448786, Val Acc: 0.761538, Val F1: 0.761035
#
# Epoch 19:
#
# Train Loss: 0.413008, Train Acc: 0.773043, Train F1: 0.773545
#
# Val Loss: 0.462361, Val Acc: 0.738462, Val F1: 0.740812
#
# Epoch 20:
#
# Train Loss: 0.432951, Train Acc: 0.781739, Train F1: 0.782359
#
# Val Loss: 0.400028, Val Acc: 0.753846, Val F1: 0.748947
#
# Epoch 21:
#
# Train Loss: 0.413572, Train Acc: 0.781739, Train F1: 0.781846
#
# Val Loss: 0.390960, Val Acc: 0.730769, Val F1: 0.725291
#
# Epoch 22:
#
# Train Loss: 0.417324, Train Acc: 0.778261, Train F1: 0.778610
#
# Val Loss: 0.359759, Val Acc: 0.769231, Val F1: 0.759143
#
# Saved best model at epoch 22
#
# Epoch 23:
#
# Train Loss: 0.379389, Train Acc: 0.796522, Train F1: 0.796576
#
# Val Loss: 0.448475, Val Acc: 0.769231, Val F1: 0.770157
#
# Epoch 24:
#
# Train Loss: 0.391388, Train Acc: 0.785217, Train F1: 0.786208
#
# Val Loss: 0.404054, Val Acc: 0.730769, Val F1: 0.709959
#
# Epoch 25:
#
# Train Loss: 0.429633, Train Acc: 0.749565, Train F1: 0.750144
#
# Val Loss: 0.397689, Val Acc: 0.746154, Val F1: 0.738358
#
# Epoch 26:
#
# Train Loss: 0.390419, Train Acc: 0.777391, Train F1: 0.777989
#
# Val Loss: 0.369845, Val Acc: 0.769231, Val F1: 0.754808
#
# Epoch 27:
#
# Train Loss: 0.356660, Train Acc: 0.794783, Train F1: 0.794556
#
# Val Loss: 0.398254, Val Acc: 0.738462, Val F1: 0.738355
#
# Epoch 28:
#
# Train Loss: 0.380694, Train Acc: 0.786957, Train F1: 0.787829
#
# Val Loss: 0.405634, Val Acc: 0.730769, Val F1: 0.726475
#
# Epoch 29:
#
# Train Loss: 0.398663, Train Acc: 0.774783, Train F1: 0.775279
#
# Val Loss: 0.400183, Val Acc: 0.723077, Val F1: 0.684127
#
# Epoch 30:
#
# Train Loss: 0.436342, Train Acc: 0.761739, Train F1: 0.761598
#
# Val Loss: 0.449141, Val Acc: 0.746154, Val F1: 0.744882
#
# Epoch 31:
#
# Train Loss: 0.405343, Train Acc: 0.786087, Train F1: 0.787314
#
# Val Loss: 0.446003, Val Acc: 0.753846, Val F1: 0.747179
#
# Epoch 32:
#
# Train Loss: 0.384106, Train Acc: 0.800000, Train F1: 0.800459
#
# Val Loss: 0.381147, Val Acc: 0.753846, Val F1: 0.743383
#
# Epoch 33:
#
# Train Loss: 0.399030, Train Acc: 0.776522, Train F1: 0.775836
#
# Val Loss: 0.520586, Val Acc: 0.700000, Val F1: 0.702709
#
# Epoch 34:
#
# Train Loss: 0.373939, Train Acc: 0.794783, Train F1: 0.795286
#
# Val Loss: 0.391584, Val Acc: 0.792308, Val F1: 0.789413
#
# Epoch 35:
#
# Train Loss: 0.368581, Train Acc: 0.789565, Train F1: 0.789753
#
# Val Loss: 0.495408, Val Acc: 0.761538, Val F1: 0.764103
#
# Epoch 36:
#
# Train Loss: 0.382601, Train Acc: 0.787826, Train F1: 0.788439
#
# Val Loss: 0.612155, Val Acc: 0.715385, Val F1: 0.719332
#
# Epoch 37:
#
# Train Loss: 0.389458, Train Acc: 0.790435, Train F1: 0.790992
#
# Val Loss: 0.428249, Val Acc: 0.792308, Val F1: 0.792729
#
# Epoch 38:
#
# Train Loss: 0.383206, Train Acc: 0.773913, Train F1: 0.774667
#
# Val Loss: 0.452091, Val Acc: 0.746154, Val F1: 0.748921
#
# Epoch 39:
#
# Train Loss: 0.379034, Train Acc: 0.790435, Train F1: 0.791341
#
# Val Loss: 0.438482, Val Acc: 0.769231, Val F1: 0.771762
#
# Epoch 40:
#
# Train Loss: 0.338180, Train Acc: 0.807826, Train F1: 0.808037
#
# Val Loss: 0.395845, Val Acc: 0.769231, Val F1: 0.770411
#
# Epoch 41:
#
# Train Loss: 0.391802, Train Acc: 0.795652, Train F1: 0.796367
#
# Val Loss: 0.442436, Val Acc: 0.746154, Val F1: 0.746813
#
# Epoch 42:
#
# Train Loss: 0.314275, Train Acc: 0.820870, Train F1: 0.821244
#
# Val Loss: 0.443142, Val Acc: 0.769231, Val F1: 0.762757
#
# Epoch 43:
#
# Train Loss: 0.352801, Train Acc: 0.798261, Train F1: 0.799012
#
# Val Loss: 0.417561, Val Acc: 0.753846, Val F1: 0.755646
#
# Epoch 44:
#
# Train Loss: 0.366847, Train Acc: 0.791304, Train F1: 0.791332
#
# Val Loss: 0.422048, Val Acc: 0.792308, Val F1: 0.793018
#
# Epoch 45:
#
# Train Loss: 0.326894, Train Acc: 0.806957, Train F1: 0.807224
#
# Val Loss: 0.453841, Val Acc: 0.769231, Val F1: 0.770857
#
# Epoch 46:
#
# Train Loss: 0.346580, Train Acc: 0.797391, Train F1: 0.798377
#
# Val Loss: 0.394409, Val Acc: 0.776923, Val F1: 0.773012
#
# Epoch 47:
#
# Train Loss: 0.363716, Train Acc: 0.793043, Train F1: 0.792957
#
# Val Loss: 0.405049, Val Acc: 0.776923, Val F1: 0.772255
#
# Epoch 48:
#
# Train Loss: 0.308094, Train Acc: 0.818261, Train F1: 0.819013
#
# Val Loss: 0.507719, Val Acc: 0.784615, Val F1: 0.787150
#
# Epoch 49:
#
# Train Loss: 0.376113, Train Acc: 0.794783, Train F1: 0.795800
#
# Val Loss: 0.442170, Val Acc: 0.776923, Val F1: 0.780365
#
# Epoch 50:
#
# Train Loss: 0.348096, Train Acc: 0.794783, Train F1: 0.795092
#
# Val Loss: 0.569123, Val Acc: 0.769231, Val F1: 0.772280
#
# Epoch 51:
#
# Train Loss: 0.332984, Train Acc: 0.806957, Train F1: 0.807568
#
# Val Loss: 0.464078, Val Acc: 0.784615, Val F1: 0.785150
#
# Epoch 52:
#
# Train Loss: 0.332029, Train Acc: 0.803478, Train F1: 0.804441
#
# Val Loss: 0.423807, Val Acc: 0.769231, Val F1: 0.766403
#
# Early stopping
#
# Saved last model
#
# Training history saved to /drive/MyDrive/Dataset/ThyroidCancerData/models/checkpoints/h3_history.json
#
# Training completed
